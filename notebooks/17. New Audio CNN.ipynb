# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import fastai
fastai.__version__
# Out:
# '1.0.37'

# %%
from fastai import *
from fastai_audio import *
from utils import *

# %%
DATA = Path('data')
AUDIO = DATA/'freesound/audio_22050_trimmed'
CSV = DATA/'freesound/audio_44KHz/train_with_lens.csv'
TEST_CSV = DATA/'freesound/audio_44KHz/test_with_lens.csv'

# %%
df = pd.read_csv(CSV)
if df['fname'].iloc[0].endswith('.wav'):
    df['fname'] = df['fname'].str[:-4]
    df.drop(['manually_verified'], axis=1, inplace=True)
df.head()
# Out:
#       fname         label  n_samples
# 0  00044347        Hi-hat     617400
# 1  001ca53d     Saxophone     455112
# 2  002d256b       Trumpet      19404
# 3  0033e230  Glockenspiel     352800
# 4  00353774         Cello     199332

# %%
n_fft = 512
n_hop = 256
n_mels = 128
sample_rate = 22050
top_db = 50.0
ref = 1.0

bs = 8

trn_batch_tfms = get_frequency_batch_transforms(
    n_fft=n_fft, n_hop=n_hop, n_mels=n_mels, 
    sample_rate=sample_rate, rand_hop_pct=0.15)

val_batch_tfms = get_frequency_batch_transforms(
    n_fft=n_fft, n_hop=n_hop, n_mels=n_mels, 
    sample_rate=sample_rate)

tfms = get_transforms(min_len=n_fft)

# %%
data = (AudioItemList
            .from_df(df, path=AUDIO, folder='train', suffix='.wav')
            .random_split_by_pct()
            .label_from_df()
            .transform(tfms)
            .databunch(bs=bs, equal_lengths=False, length_col=2))
len(data.train_ds), len(data.valid_ds)
# Out:
# (7579, 1894)

# %%
data.train_dl.add_tfm(trn_batch_tfms[0])
data.valid_dl.add_tfm(val_batch_tfms[0])

# %%
res_block(32)
# Out:
# SequentialEx(
#   (layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): ReLU(inplace)
#       (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): ReLU(inplace)
#       (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): MergeLayer()
#   )
# )

# %%
class AudioResNet(nn.Module):
    def __init__(self, n_classes):
        super().__init__()
        n_filters = [16, 32, 64, 128, 256, 512, 1024]
        layers = [conv2d(1, n_filters[0])]
        for in_filters, out_filters in zip(n_filters[:-1], n_filters[1:]):
            layers += [res_block(in_filters),
                       conv2d(in_filters, out_filters, stride=2)]
        layers += [PoolFlatten(),
                   *bn_drop_lin(n_filters[-1], 1024, p=0.25),
                   *bn_drop_lin(1024,     n_classes, p=0.5)]
        self.layers = nn.Sequential(*layers)
            
    def forward(self, x):
        return self.layers(x)

# %%
model = AudioResNet(data.c)

# %%
learn = Learner(data, model)
learn.summary()
# Out:
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [8, 16, 128, 2248]   144        True
# ______________________________________________________________________
# Conv2d               [8, 16, 128, 2248]   2304       True
# ______________________________________________________________________
# ReLU                 [8, 16, 128, 2248]   0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 16, 128, 2248]   32         True
# ______________________________________________________________________
# Conv2d               [8, 16, 128, 2248]   2304       True
# ______________________________________________________________________
# ReLU                 [8, 16, 128, 2248]   0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 16, 128, 2248]   32         True
# ______________________________________________________________________
# MergeLayer           [8, 16, 128, 2248]   0          False
# ______________________________________________________________________
# Conv2d               [8, 32, 64, 1124]    4608       True
# ______________________________________________________________________
# Conv2d               [8, 32, 64, 1124]    9216       True
# ______________________________________________________________________
# ReLU                 [8, 32, 64, 1124]    0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 32, 64, 1124]    64         True
# ______________________________________________________________________
# Conv2d               [8, 32, 64, 1124]    9216       True
# ______________________________________________________________________
# ReLU                 [8, 32, 64, 1124]    0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 32, 64, 1124]    64         True
# ______________________________________________________________________
# MergeLayer           [8, 32, 64, 1124]    0          False
# ______________________________________________________________________
# Conv2d               [8, 64, 32, 562]     18432      True
# ______________________________________________________________________
# Conv2d               [8, 64, 32, 562]     36864      True
# ______________________________________________________________________
# ReLU                 [8, 64, 32, 562]     0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 64, 32, 562]     128        True
# ______________________________________________________________________
# Conv2d               [8, 64, 32, 562]     36864      True
# ______________________________________________________________________
# ReLU                 [8, 64, 32, 562]     0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 64, 32, 562]     128        True
# ______________________________________________________________________
# MergeLayer           [8, 64, 32, 562]     0          False
# ______________________________________________________________________
# Conv2d               [8, 128, 16, 281]    73728      True
# ______________________________________________________________________
# Conv2d               [8, 128, 16, 281]    147456     True
# ______________________________________________________________________
# ReLU                 [8, 128, 16, 281]    0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 128, 16, 281]    256        True
# ______________________________________________________________________
# Conv2d               [8, 128, 16, 281]    147456     True
# ______________________________________________________________________
# ReLU                 [8, 128, 16, 281]    0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 128, 16, 281]    256        True
# ______________________________________________________________________
# MergeLayer           [8, 128, 16, 281]    0          False
# ______________________________________________________________________
# Conv2d               [8, 256, 8, 141]     294912     True
# ______________________________________________________________________
# Conv2d               [8, 256, 8, 141]     589824     True
# ______________________________________________________________________
# ReLU                 [8, 256, 8, 141]     0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 256, 8, 141]     512        True
# ______________________________________________________________________
# Conv2d               [8, 256, 8, 141]     589824     True
# ______________________________________________________________________
# ReLU                 [8, 256, 8, 141]     0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 256, 8, 141]     512        True
# ______________________________________________________________________
# MergeLayer           [8, 256, 8, 141]     0          False
# ______________________________________________________________________
# Conv2d               [8, 512, 4, 71]      1179648    True
# ______________________________________________________________________
# Conv2d               [8, 512, 4, 71]      2359296    True
# ______________________________________________________________________
# ReLU                 [8, 512, 4, 71]      0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 512, 4, 71]      1024       True
# ______________________________________________________________________
# Conv2d               [8, 512, 4, 71]      2359296    True
# ______________________________________________________________________
# ReLU                 [8, 512, 4, 71]      0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 512, 4, 71]      1024       True
# ______________________________________________________________________
# MergeLayer           [8, 512, 4, 71]      0          False
# ______________________________________________________________________
# Conv2d               [8, 1024, 2, 36]     4718592    True
# ______________________________________________________________________
# AdaptiveAvgPool2d    [8, 1024, 1, 1]      0          False
# ______________________________________________________________________
# Lambda               [8, 1024]            0          False
# ______________________________________________________________________
# BatchNorm1d          [8, 1024]            2048       True
# ______________________________________________________________________
# Dropout              [8, 1024]            0          False
# ______________________________________________________________________
# Linear               [8, 1024]            1049600    True
# ______________________________________________________________________
# BatchNorm1d          [8, 1024]            2048       True
# ______________________________________________________________________
# Dropout              [8, 1024]            0          False
# ______________________________________________________________________
# Linear               [8, 41]              42025      True
# ______________________________________________________________________
#
# Total params:  13679737
# Total trainable params:  13679737
# Total non-trainable params:  0

# %%
cut = -7
learn = create_audio_cnn(data, model, cut)
learn.summary()
# Out:
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [8, 16, 128, 2360]   144        False
# ______________________________________________________________________
# Conv2d               [8, 16, 128, 2360]   2304       False
# ______________________________________________________________________
# ReLU                 [8, 16, 128, 2360]   0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 16, 128, 2360]   32         True
# ______________________________________________________________________
# Conv2d               [8, 16, 128, 2360]   2304       False
# ______________________________________________________________________
# ReLU                 [8, 16, 128, 2360]   0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 16, 128, 2360]   32         True
# ______________________________________________________________________
# MergeLayer           [8, 16, 128, 2360]   0          False
# ______________________________________________________________________
# Conv2d               [8, 32, 64, 1180]    4608       False
# ______________________________________________________________________
# Conv2d               [8, 32, 64, 1180]    9216       False
# ______________________________________________________________________
# ReLU                 [8, 32, 64, 1180]    0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 32, 64, 1180]    64         True
# ______________________________________________________________________
# Conv2d               [8, 32, 64, 1180]    9216       False
# ______________________________________________________________________
# ReLU                 [8, 32, 64, 1180]    0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 32, 64, 1180]    64         True
# ______________________________________________________________________
# MergeLayer           [8, 32, 64, 1180]    0          False
# ______________________________________________________________________
# Conv2d               [8, 64, 32, 590]     18432      False
# ______________________________________________________________________
# Conv2d               [8, 64, 32, 590]     36864      False
# ______________________________________________________________________
# ReLU                 [8, 64, 32, 590]     0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 64, 32, 590]     128        True
# ______________________________________________________________________
# Conv2d               [8, 64, 32, 590]     36864      False
# ______________________________________________________________________
# ReLU                 [8, 64, 32, 590]     0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 64, 32, 590]     128        True
# ______________________________________________________________________
# MergeLayer           [8, 64, 32, 590]     0          False
# ______________________________________________________________________
# Conv2d               [8, 128, 16, 295]    73728      False
# ______________________________________________________________________
# Conv2d               [8, 128, 16, 295]    147456     False
# ______________________________________________________________________
# ReLU                 [8, 128, 16, 295]    0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 128, 16, 295]    256        True
# ______________________________________________________________________
# Conv2d               [8, 128, 16, 295]    147456     False
# ______________________________________________________________________
# ReLU                 [8, 128, 16, 295]    0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 128, 16, 295]    256        True
# ______________________________________________________________________
# MergeLayer           [8, 128, 16, 295]    0          False
# ______________________________________________________________________
# Conv2d               [8, 256, 8, 148]     294912     False
# ______________________________________________________________________
# Conv2d               [8, 256, 8, 148]     589824     False
# ______________________________________________________________________
# ReLU                 [8, 256, 8, 148]     0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 256, 8, 148]     512        True
# ______________________________________________________________________
# Conv2d               [8, 256, 8, 148]     589824     False
# ______________________________________________________________________
# ReLU                 [8, 256, 8, 148]     0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 256, 8, 148]     512        True
# ______________________________________________________________________
# MergeLayer           [8, 256, 8, 148]     0          False
# ______________________________________________________________________
# Conv2d               [8, 512, 4, 74]      1179648    False
# ______________________________________________________________________
# Conv2d               [8, 512, 4, 74]      2359296    False
# ______________________________________________________________________
# ReLU                 [8, 512, 4, 74]      0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 512, 4, 74]      1024       True
# ______________________________________________________________________
# Conv2d               [8, 512, 4, 74]      2359296    False
# ______________________________________________________________________
# ReLU                 [8, 512, 4, 74]      0          False
# ______________________________________________________________________
# BatchNorm2d          [8, 512, 4, 74]      1024       True
# ______________________________________________________________________
# MergeLayer           [8, 512, 4, 74]      0          False
# ______________________________________________________________________
# Conv2d               [8, 1024, 2, 37]     4718592    False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [8, 1024, 1, 1]      0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [8, 1024, 1, 1]      0          False
# ______________________________________________________________________
# Lambda               [8, 2048]            0          False
# ______________________________________________________________________
# BatchNorm1d          [8, 2048]            4096       True
# ______________________________________________________________________
# Dropout              [8, 2048]            0          False
# ______________________________________________________________________
# Linear               [8, 512]             1049088    True
# ______________________________________________________________________
# ReLU                 [8, 512]             0          False
# ______________________________________________________________________
# BatchNorm1d          [8, 512]             1024       True
# ______________________________________________________________________
# Dropout              [8, 512]             0          False
# ______________________________________________________________________
# Linear               [8, 41]              21033      True
# ______________________________________________________________________
#
# Total params:  13659257
# Total trainable params:  1079273
# Total non-trainable params:  12579984
